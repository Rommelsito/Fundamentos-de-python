# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_titanic = pd.read_csv('Titanic-Dataset.csv')

# %%
df_titanic.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df_matl = df_titanic[['Age', 'Fare']]

# %%
df_matl
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df_matl.plot()
# Out:
# <Axes: >

# %%
#Representacion grafica de 
df_matl['Fare'].plot()
# Out:
# <Axes: >

# %%
df_matl.plot.scatter(y = 'Fare', x = 'Age')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
#Agregar categoria de edads: Infante, Adolescente, Adulto, Adulto
# Niños < 12, Adolescentes 12-17, Adultos > 18-55, Adulto mayor 56
df_1 = df_titanic[['Name', 'Age', "Sex"]]

# %%
df_clean = df_1[df_1['Age'].notna()]

# %%
df_clean['Category'] = df_clean['Age']
# Out:
# C:\Users\lacar\AppData\Local\Temp\ipykernel_22732\780792599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Category'] = df_clean['Age']

# %%
#Contruir funcion para definir categoria 
# Niños < 12, Adolescentes 12-17, Adultos > 18-55, Adulto mayor 56

def category(Age):
    if Age <= 12:
        return 'child'
    elif Age > 12 and Age <= 17:
        return 'adolescent'
    elif Age > 18 and Age <= 55:
        return 'Adulto'
    else:
        return 'Adulto mayor'

# %%
category(5)
# Out:
# 'child'

# %%
df_clean['Category'] = df_clean['Category'].apply(category)
# Out:
# C:\Users\lacar\AppData\Local\Temp\ipykernel_22732\4143672415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['Category'] = df_clean['Category'].apply(category)

# %%
df_clean.head(20)
# Out:
#                                                  Name   Age     Sex  \
# 0                             Braund, Mr. Owen Harris  22.0    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss. Laina  26.0  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                            Allen, Mr. William Henry  35.0    male
# 6                             McCarthy, Mr. Timothy J  54.0    male
# 7                      Palsson, Master. Gosta Leonard   2.0    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# 10                    Sandstrom, Miss. Marguerite Rut   4.0  female
# 11                           Bonnell, Miss. Elizabeth  58.0  female
# 12                     Saundercock, Mr. William Henry  20.0    male
# 13                        Andersson, Mr. Anders Johan  39.0    male
# ...

# %% [markdown]
# #### Estadistica basicas

# %%
df_titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# describe -> Estadisticas descrptivas

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
col_list = df_titanic.columns.to_list()

# %%
print(col_list)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
#sort nos permite ordenar los datos dd manera alfabetica
col_list.sort()

# %%
col_list
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'Ticket']

# %%
col_list_1 = ['Age',"Fare", 'Cabin', 'Embarked', 'Name', 'Parch', 'PassengerId', 'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket']

# %%
col_list_1[:2]
# Out:
# ['Age', 'Fare']

# %%
# Descripcion de un par o mas atributos
df_titanic[col_list_1[:2]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
# Ver estadisticas especificas de un conjunto de atributos que em muestra mi describe
df_titanic.agg(
    {
        "Age": ["min", "max", "mean"],
        "Fare": ["min", "max", "mean"],
    }
)
# Out:
#             Age        Fare
# min    0.420000    0.000000
# max   80.000000  512.329200
# mean  29.699118   32.204208

# %% [markdown]
# ##### .groupby(). Me permite agrupar categorias o agrupar datos categoricos

# %%
data = {
    "category": ["A", "B","A","A","B","C","C","C"],
    "values" : [10, 20, 12, 30, 40, 50, 60, 70],
    "Quantity" : [1, 2, 3, 4, 5, 6, 7, 8]
}

# %%
df_101 = pd.DataFrame(data)
print(df_101)
# Out:
#   category  values  Quantity
# 0        A      10         1
# 1        B      20         2
# 2        A      12         3
# 3        A      30         4
# 4        B      40         5
# 5        C      50         6
# 6        C      60         7
# 7        C      70         8

# %%
#Suma de los valores por categoria
df_101.groupby("category")["values"].sum()
# Out:
# category
# A     52
# B     60
# C    180
# Name: values, dtype: int64

# %%
df_titanic.head(12)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#Promedio de la edad por sexo
df_titanic[["Sex", "Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df_clean.head(12)
# Out:
#                                                  Name   Age     Sex  \
# 0                             Braund, Mr. Owen Harris  22.0    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss. Laina  26.0  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                            Allen, Mr. William Henry  35.0    male
# 6                             McCarthy, Mr. Timothy J  54.0    male
# 7                      Palsson, Master. Gosta Leonard   2.0    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# 10                    Sandstrom, Miss. Marguerite Rut   4.0  female
# 11                           Bonnell, Miss. Elizabeth  58.0  female
# 12                     Saundercock, Mr. William Henry  20.0    male
#
#         Category
# 0         Adulto
# 1         Adulto
# 2         Adulto
# ...

# %%
df_clean["Fare"] = df_titanic["Fare"]
# Out:
# C:\Users\lacar\AppData\Local\Temp\ipykernel_22732\3263006899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["Fare"] = df_titanic["Fare"]

# %%
df_clean
# Out:
#                                                   Name   Age     Sex Category  \
# 0                              Braund, Mr. Owen Harris  22.0    male   Adulto
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female   Adulto
# 2                               Heikkinen, Miss. Laina  26.0  female   Adulto
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female   Adulto
# 4                             Allen, Mr. William Henry  35.0    male   Adulto
# ..                                                 ...   ...     ...      ...
# 885               Rice, Mrs. William (Margaret Norton)  39.0  female   Adulto
# 886                              Montvila, Rev. Juozas  27.0    male   Adulto
# 887                       Graham, Miss. Margaret Edith  19.0  female   Adulto
# 889                              Behr, Mr. Karl Howell  26.0    male   Adulto
# 890                                Dooley, Mr. Patrick  32.0    male   Adulto
#
#         Fare
# 0     7.2500
# ...

# %%
df_clean[["Category", "Fare"]].groupby("Category").count()
# Out:
#               Fare
# Category
# Adulto         535
# Adulto mayor    66
# adolescent      44
# child           69

# %%
df_clean.groupby(["Sex","Category"])["Fare"].count()
# Out:
# Sex     Category
# female  Adulto          184
#         Adulto mayor     22
#         adolescent       23
#         child            32
# male    Adulto          351
#         Adulto mayor     44
#         adolescent       21
#         child            37
# Name: Fare, dtype: int64

# %%
#Contar los valores de una categoria
df_clean["Category"].value_counts()
# Out:
# Category
# Adulto          535
# child            69
# Adulto mayor     66
# adolescent       44
# Name: count, dtype: int64

# %%
df_clean.head(12)
# Out:
#                                                  Name   Age     Sex  \
# 0                             Braund, Mr. Owen Harris  22.0    male
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female
# 2                              Heikkinen, Miss. Laina  26.0  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female
# 4                            Allen, Mr. William Henry  35.0    male
# 6                             McCarthy, Mr. Timothy J  54.0    male
# 7                      Palsson, Master. Gosta Leonard   2.0    male
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0  female
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0  female
# 10                    Sandstrom, Miss. Marguerite Rut   4.0  female
# 11                           Bonnell, Miss. Elizabeth  58.0  female
# 12                     Saundercock, Mr. William Henry  20.0    male
#
#         Category     Fare
# 0         Adulto   7.2500
# 1         Adulto  71.2833
# ...

# %%
# Ordenar el df por category con el metodo sort_values(ordena el dato seleccionado de - a +)
df_clean.sort_values(["Age", "Fare"]).head(20)
# Out:
#                                 Name   Age     Sex Category      Fare
# 803  Thomas, Master. Assad Alexander  0.42    male    child    8.5167
# 755        Hamalainen, Master. Viljo  0.67    male    child   14.5000
# 469    Baclini, Miss. Helene Barbara  0.75  female    child   19.2583
# 644           Baclini, Miss. Eugenie  0.75  female    child   19.2583
# 831  Richards, Master. George Sibley  0.83    male    child   18.7500
# 78     Caldwell, Master. Alden Gates  0.83    male    child   29.0000
# 305   Allison, Master. Hudson Trevor  0.92    male    child  151.5500
# 172     Johnson, Miss. Eleanor Ileen  1.00  female    child   11.1333
# 381      Nakid, Miss. Maria ("Mary")  1.00  female    child   15.7417
# 788       Dean, Master. Bertram Vere  1.00    male    child   20.5750
# 827            Mallet, Master. Andre  1.00    male    child   37.0042
# 183        Becker, Master. Richard F  1.00    male    child   39.0000
# ...

# %%
# Ordenar df con uno o mas atributos de + a
df_clean.sort_values(["Age", "Fare"], ascending = False).head(20)
# Out:
#                                           Name   Age     Sex      Category  \
# 630       Barkworth, Mr. Algernon Henry Wilson  80.0    male  Adulto mayor
# 851                        Svensson, Mr. Johan  74.0    male  Adulto mayor
# 493                    Artagaveytia, Mr. Ramon  71.0    male  Adulto mayor
# 96                   Goldschmidt, Mr. George B  71.0    male  Adulto mayor
# 116                       Connors, Mr. Patrick  70.5    male  Adulto mayor
# 745               Crosby, Capt. Edward Gifford  70.0    male  Adulto mayor
# 672                Mitchell, Mr. Henry Michael  70.0    male  Adulto mayor
# 33                       Wheadon, Mr. Edward H  66.0    male  Adulto mayor
# 54              Ostby, Mr. Engelhart Cornelius  65.0    male  Adulto mayor
# 456                  Millet, Mr. Francis Davis  65.0    male  Adulto mayor
# 280                           Duane, Mr. Frank  65.0    male  Adulto mayor
# ...

# %%
df_plot4 = df_clean[["Category", "Fare"]].groupby("Category").min()

# %%
df_plot4.plot()
# Out:
# <Axes: xlabel='Category'>
