# %%
import pandas as pd

# %%
df_titanic = pd.read_csv("Titanic-Dataset.csv")

# %%
#Nos da informacion total del arhivo
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic.head(12)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df_titanic["Survived"].sum()
# Out:
# 342

# %%
df_titanic["Age"].min()
# Out:
# 0.42

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic.tail(6)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C
# ...

# %%
df_titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ##### Seleccion de subconjuntos de Datos

# %%
df_titanic.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df_2 = df_titanic[["Age", "Survived", "Name", "Sex"]]

# %%
df_2.head(12)
# Out:
#      Age  Survived                                               Name     Sex
# 0   22.0         0                            Braund, Mr. Owen Harris    male
# 1   38.0         1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2   26.0         1                             Heikkinen, Miss. Laina  female
# 3   35.0         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4   35.0         0                           Allen, Mr. William Henry    male
# 5    NaN         0                                   Moran, Mr. James    male
# 6   54.0         0                            McCarthy, Mr. Timothy J    male
# 7    2.0         0                     Palsson, Master. Gosta Leonard    male
# 8   27.0         1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9   14.0         1                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10   4.0         1                    Sandstrom, Miss. Marguerite Rut  female
# ...

# %%
df_2.shape
# Out:
# (891, 4)

# %%
"""
lista1 = ["Name", 'Sex','Age','Survived']
df_1 = df_titanic[lista1]
"""

# %%
#df_1.head(5)

# %% [markdown]
# Seleccion

# %%
#Pasageros mayor a 30
df_30 = df_titanic[df_titanic['Age'] > 30]

# %%
df_30.head(12)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 4             5         0       3
# 6             7         0       1
# 11           12         1       1
# 13           14         0       3
# 15           16         1       2
# 18           19         0       3
# 20           21         0       2
# 21           22         1       2
# 25           26         1       3
# 30           31         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
df_30.shape
# Out:
# (305, 12)

# %%
#Clases de pasajeros de la embarcacion

df_titanic['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
#Pasajeros que iban en 2da y 3ra clase
df_class23 = df_titanic[df_titanic['Pclass'].isin([2,3])]

# %%
df_class23.shape
# Out:
# (675, 12)

# %%
#Pasajeros de la clase 3
df_class3 = df_titanic[df_titanic['Pclass'].isin([3])]

# %%
df_class3
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#Calculo de porcentaje de pasajeros que iban en 3ra clase
df_class3.shape[0] *100 / df_titanic.shape[0]
# Out:
# 55.10662177328844

# %%
## Pasajeros con pertenecias en la clase 2 y 3 con el operador 'or' en panda 

df_or = df_titanic[(df_titanic['Pclass'] == 2) | (df_titanic['Pclass'] == 3 )]

# %%
df_or.shape
# Out:
# (675, 12)

# %%
df_or.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 675 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  675 non-null    int64
#  1   Survived     675 non-null    int64
#  2   Pclass       675 non-null    int64
#  3   Name         675 non-null    object
#  4   Sex          675 non-null    object
#  5   Age          528 non-null    float64
#  6   SibSp        675 non-null    int64
#  7   Parch        675 non-null    int64
#  8   Ticket       675 non-null    object
#  9   Fare         675 non-null    float64
#  10  Cabin        28 non-null     object
#  11  Embarked     675 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 68.6+ KB

# %%
#Pasajeros de la clase 2 y 3 con edad valida 
#notna muetra filas con valores validos 
df_val = df_or[df_or['Age'].notna()]

# %%
df_val
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_inv= df_val[df_val['Age'].isna()]

# %%
df_inv
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df_titanic[df_titanic['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
#Filtros de filas y columnas 

df_titanic.loc[df_titanic['Age'] > 30, ['Name', 'Sex']].head(20)
# Out:
#                                                  Name     Sex
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                            Allen, Mr. William Henry    male
# 6                             McCarthy, Mr. Timothy J    male
# 11                           Bonnell, Miss. Elizabeth  female
# 13                        Andersson, Mr. Anders Johan    male
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 20                               Fynney, Mr. Joseph J    male
# 21                              Beesley, Mr. Lawrence    male
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female
# 30                           Uruchurtu, Don. Manuel E    male
# 33                              Wheadon, Mr. Edward H    male
# 35                     Holverson, Mr. Alexander Oskar    male
# ...

# %%
#Filtro por indice 
df_titanic.iloc[:10, :5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
# 5                                   Moran, Mr. James    male
# 6                            McCarthy, Mr. Timothy J    male
# 7                     Palsson, Master. Gosta Leonard    male
# ...
